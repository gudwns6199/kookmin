# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ### Hello world

# %% [markdown]
# ### Hi !

# %%
print('Bye world')
# Out:
# Bye world

# %% [markdown]
# ### This is Header!
#
# This is body

# %% [markdown]
# **이탈리체**
# __이탈리체__
#
# _기울어진 서식_
# *기울어친 서식*
#
# ~불닭볶음면~

# %% [markdown]
# # 1
# ## 2
# ### 3
# #### 4
# ##### 5
# ###### 6

# %% [markdown]
# 4. one
# 8. two
# 10. three
#
# - father
# - mother
# - me
#
#
# * father
# * mother
# * me
